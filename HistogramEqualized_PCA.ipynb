# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv('E:\project\HistogramEqualized.csv')

# %%
X=dataset.iloc[:,0:625].values
y=dataset.iloc[:,625].values

# %%
X
# Out:
# array([[ 41,  42,  43, ...,  86,  58,  39],
#        [  0,   0,  24, ...,  34,  29,   5],
#        [ 39,  38,  37, ...,  36,  36,  21],
#        ...,
#        [ 11,  10,   8, ..., 182,  43,  89],
#        [ 11,   7,   9, ..., 185, 139,  29],
#        [164, 184, 215, ..., 250, 239, 224]], dtype=int64)

# %%
y
# Out:
# array(['Covid', 'Covid', 'Covid', ..., 'Non-Covid', 'Non-Covid',
#        'Non-Covid'], dtype=object)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
X_train.shape
# Out:
# (12753, 625)

# %%
X_test.shape
# Out:
# (3189, 625)

# %%
y_train.shape
# Out:
# (12753,)

# %%
y_test.shape
# Out:
# (3189,)

# %%
X_train
# Out:
# array([[26, 32, 30, ..., 25, 15,  0],
#        [16, 14, 17, ..., 15, 15,  9],
#        [16, 45, 46, ..., 41, 40, 13],
#        ...,
#        [39, 41, 41, ..., 93, 59, 31],
#        [34, 34, 35, ..., 28, 32, 36],
#        [ 0,  2, 24, ..., 10,  0,  0]], dtype=int64)

# %%
X_test
# Out:
# array([[ 28,  30,  30, ...,   3,   0,   0],
#        [  0,  31, 167, ..., 175, 168, 155],
#        [ 26,  26,  28, ...,  24,  25,  26],
#        ...,
#        [ 39,  39,  39, ...,  39,  36,  35],
#        [ 13,  12,  13, ...,  32,  41,  72],
#        [ 34,  36,  36, ...,  31,  33,  34]], dtype=int64)

# %%
y_train
# Out:
# array(['Non-Covid', 'Covid', 'Non-Covid', ..., 'Non-Covid', 'Non-Covid',
#        'Covid'], dtype=object)

# %%
y_test
# Out:
# array(['Covid', 'Non-Covid', 'Covid', ..., 'Covid', 'Non-Covid', 'Covid'],
#       dtype=object)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc_X=StandardScaler()
sc_X=sc_X.fit(X_train)

# %%
X_train=sc_X.transform(X_train)
X_test=sc_X.transform(X_test)

# %%
import pickle

# %%
with open("sc_henor.pk","wb") as f:
    pickle.dump(sc_X, f)

# %%
with open('sc_henor.pk', 'rb') as pickle_file:
    sc_X = pickle.load(pickle_file)

# %%
sc_X
# Out:
# StandardScaler()

# %%
X_train=sc_X.transform(X_train)
X_test=sc_X.transform(X_test)

# %%
#Feature Scaling
#Standardize the data
#X_std=(x-mean(x))/std_dev(x)

# %%
sc_X=StandardScaler()
X_train=sc_X.fit_transform(X_train)
X_test=sc_X.transform(X_test)

# %%
X_train
# Out:
# array([[-0.03172516, -0.03862989, -0.23568232, ..., -0.55060319,
#         -0.59743715, -0.74486521],
#        [-0.34791067, -0.58730245, -0.61006106, ..., -0.76086003,
#         -0.59743715, -0.54446486],
#        [-0.34791067,  0.35763363,  0.22509153, ..., -0.21419225,
#         -0.05648502, -0.45539804],
#        ...,
#        [ 0.379316  ,  0.23570639,  0.0810997 , ...,  0.87914331,
#          0.35463859, -0.05459734],
#        [ 0.22122325,  0.02233373, -0.09169049, ..., -0.48752614,
#         -0.2295897 ,  0.05673619],
#        [-0.85380749, -0.95308416, -0.40847251, ..., -0.86598845,
#         -0.92200842, -0.74486521]])

# %%
X_test
# Out:
# array([[ 0.03151194, -0.09959351, -0.23568232, ..., -1.01316824,
#         -0.92200842, -0.74486521],
#        [-0.85380749, -0.0691117 ,  3.70969371, ...,  2.60324939,
#          2.71318985,  2.70647415],
#        [-0.03172516, -0.22152074, -0.29327905, ..., -0.57162888,
#         -0.3810563 , -0.16593087],
#        ...,
#        [ 0.379316  ,  0.17474277,  0.02350297, ..., -0.25624362,
#         -0.14303736,  0.03446948],
#        [-0.44276633, -0.64826607, -0.72525452, ..., -0.40342341,
#         -0.03484694,  0.85833759],
#        [ 0.22122325,  0.08329735, -0.06289212, ..., -0.42444909,
#         -0.20795162,  0.01220278]])

# %%
#PCA for dimensionality reduction

# %%
from sklearn.decomposition import PCA

# %%
pca=PCA(n_components=0.90)

# %%
pca_model=pca.fit(X_train)
X_train_pca=pca.transform(X_train)
X_test_pca=pca.transform(X_test)

# %%
import pickle

# %%
with open("pca_henor.pk","wb") as f:
    pickle.dump(pca_model, f)

# %%
with open('pca_henor.pk', 'rb') as pickle_file:
    pca_model = pickle.load(pickle_file)

# %%
pca_model.n_components_
# Out:
# 73

# %%
X_train_pca=pca_model.transform(X_train)
X_test_pca=pca_model.transform(X_test)

# %%
pca.n_components_
# Out:
# 73

# %%
X_train_pca
# Out:
# array([[ -5.84728162,  17.42656919,   1.80926405, ...,   0.89551405,
#          -0.46140783,   0.30792577],
#        [ -5.51879435,  17.57707635,   1.43580851, ...,  -1.0349049 ,
#          -1.18352034,   1.48735306],
#        [ -8.06187372,   6.74988081,   7.38563775, ...,   1.06152276,
#           0.2526667 ,  -0.11172124],
#        ...,
#        [  0.21864636, -13.21070857,   1.15703794, ...,  -0.46703081,
#          -0.28698138,   0.36789741],
#        [ -3.8478824 ,  -9.17412304,  -2.37378789, ...,   0.10853137,
#           0.35675031,  -0.94788766],
#        [ -9.31000202,   8.82822111,  -2.53700144, ...,  -0.3243463 ,
#           0.4711072 ,   0.81589072]])

# %%
X_train_pca.shape
# Out:
# (12753, 73)

# %%
X_test_pca.shape
# Out:
# (3189, 73)

# %%
explained_var=pca.explained_variance_ratio_
explained_var
# Out:
# array([0.25487692, 0.11534218, 0.08564466, 0.05318726, 0.03353602,
#        0.02692048, 0.02229275, 0.02174153, 0.01819655, 0.01748911,
#        0.01475166, 0.01426554, 0.01300537, 0.01241367, 0.01171681,
#        0.01010833, 0.00795285, 0.00763248, 0.00734985, 0.00701217,
#        0.00653639, 0.00629736, 0.00604013, 0.00563659, 0.00519366,
#        0.00500926, 0.00473305, 0.00434627, 0.00413208, 0.00385885,
#        0.00384707, 0.00374322, 0.00362671, 0.00348458, 0.00315416,
#        0.0031026 , 0.00302689, 0.00288724, 0.00274255, 0.00267728,
#        0.00264267, 0.00259973, 0.00256078, 0.00251819, 0.00244226,
#        0.00237497, 0.00231304, 0.00219876, 0.00217198, 0.0021258 ,
#        0.00210459, 0.00203968, 0.00202747, 0.00190225, 0.00188461,
#        0.00184698, 0.0018277 , 0.00178998, 0.00175705, 0.00165401,
#        0.00162925, 0.00160548, 0.00156804, 0.00154236, 0.0015218 ,
#        0.00145909, 0.00141576, 0.00140484, 0.00138099, 0.00132944,
# ...

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

# %%
#Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
logreg = LogisticRegression()
logreg.fit(X_train_pca,y_train)
# Out:
# LogisticRegression()

# %%
y_pred_logreg=logreg.predict(X_test_pca)

# %%
y_pred_logreg
# Out:
# array(['Covid', 'Non-Covid', 'Covid', ..., 'Non-Covid', 'Covid', 'Covid'],
#       dtype=object)

# %%
conf_matrix = confusion_matrix(y_test,y_pred_logreg)
conf_matrix
# Out:
# array([[1193,  400],
#        [ 477, 1119]], dtype=int64)

# %%
accuracy_score(y_test, y_pred_logreg)
# Out:
# 0.7249921605518972

# %%
precision_score(y_test, y_pred_logreg,average='weighted')
# Out:
# 0.7255305473433052

# %%
recall_score(y_test, y_pred_logreg, average='weighted')
# Out:
# 0.7249921605518972

# %%
f1_score(y_test, y_pred_logreg, average='weighted')
# Out:
# 0.7248379932065434

# %%
recall_score(y_test, y_pred_logreg, pos_label='Non-Covid')
# Out:
# 0.7011278195488722

# %%
#Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

# %%
nb = GaussianNB()
nb.fit(X_train_pca,y_train)
# Out:
# GaussianNB()

# %%
y_pred_nb=nb.predict(X_test_pca)

# %%
y_pred_nb
# Out:
# array(['Covid', 'Non-Covid', 'Covid', ..., 'Covid', 'Non-Covid', 'Covid'],
#       dtype='<U9')

# %%
conf_matrix = confusion_matrix(y_test,y_pred_nb)
conf_matrix
# Out:
# array([[1312,  281],
#        [ 958,  638]], dtype=int64)

# %%
accuracy_score(y_test, y_pred_nb)
# Out:
# 0.6114769520225776

# %%
precision_score(y_test, y_pred_nb,average='weighted')
# Out:
# 0.6361578995660083

# %%
recall_score(y_test, y_pred_nb, average='weighted')
# Out:
# 0.6114769520225776

# %%
f1_score(y_test, y_pred_nb, average='weighted')
# Out:
# 0.5932294821695753

# %%
recall_score(y_test, y_pred_nb, pos_label='Non-Covid')
# Out:
# 0.39974937343358397

# %%
#KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train_pca,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
with open("knn_henor.pk","wb") as f:
    pickle.dump(knn, f)

# %%
with open('knn_henor.pk', 'rb') as pickle_file:
    knn = pickle.load(pickle_file)

# %%
y_pred_knn=knn.predict(X_test_pca)

# %%
y_pred_knn
# Out:
# array(['Covid', 'Non-Covid', 'Covid', ..., 'Covid', 'Non-Covid', 'Covid'],
#       dtype=object)

# %%
conf_matrix = confusion_matrix(y_test,y_pred_knn)
conf_matrix
# Out:
# array([[1593,    0],
#        [   5, 1591]], dtype=int64)

# %%
accuracy_score(y_test, y_pred_knn)
# Out:
# 0.9984321103794292

# %%
precision_score(y_test, y_pred_knn,average='weighted')
# Out:
# 0.9984370161667276

# %%
recall_score(y_test, y_pred_knn, average='weighted')
# Out:
# 0.9984321103794292

# %%
f1_score(y_test, y_pred_knn, average='weighted')
# Out:
# 0.9984321088377054

# %%
recall_score(y_test, y_pred_knn, pos_label='Non-Covid')
# Out:
# 0.9968671679197995

# %%
#Decision Tree

# %%
from sklearn import tree

# %%
dt = tree.DecisionTreeClassifier()
dt=dt.fit(X_train_pca, y_train)

# %%
dt.tree_.node_count
# Out:
# 1093

# %%
dt.tree_.max_depth
# Out:
# 26

# %%
y_pred_dt=dt.predict(X_test_pca)

# %%
y_pred_dt
# Out:
# array(['Covid', 'Non-Covid', 'Covid', ..., 'Covid', 'Non-Covid', 'Covid'],
#       dtype=object)

# %%
conf_matrix = confusion_matrix(y_test,y_pred_dt)
conf_matrix
# Out:
# array([[1490,  103],
#        [ 112, 1484]], dtype=int64)

# %%
accuracy_score(y_test, y_pred_dt)
# Out:
# 0.9325807463154594

# %%
precision_score(y_test, y_pred_dt,average='weighted')
# Out:
# 0.9325948863280525

# %%
recall_score(y_test, y_pred_dt, average='weighted')
# Out:
# 0.9325807463154594

# %%
f1_score(y_test, y_pred_dt, average='weighted')
# Out:
# 0.9325803883260331

# %%
recall_score(y_test, y_pred_dt, pos_label='Non-Covid')
# Out:
# 0.9298245614035088

# %%
#Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()
rf.fit(X_train_pca, y_train)
# Out:
# RandomForestClassifier()

# %%
with open("rf_henor.pk","wb") as f:
    pickle.dump(rf, f)

# %%
with open('rf_henor.pk', 'rb') as pickle_file:
    rf = pickle.load(pickle_file)

# %%
y_pred_rf=rf.predict(X_test_pca)

# %%
y_pred_rf
# Out:
# array(['Covid', 'Non-Covid', 'Covid', ..., 'Covid', 'Non-Covid', 'Covid'],
#       dtype=object)

# %%
conf_matrix = confusion_matrix(y_test,y_pred_rf)
conf_matrix
# Out:
# array([[1592,    1],
#        [   2, 1594]], dtype=int64)

# %%
accuracy_score(y_test, y_pred_rf)
# Out:
# 0.9990592662276576

# %%
precision_score(y_test, y_pred_rf,average='weighted')
# Out:
# 0.9990594630749128

# %%
recall_score(y_test, y_pred_rf, average='weighted')
# Out:
# 0.9990592662276576

# %%
f1_score(y_test, y_pred_rf, average='weighted')
# Out:
# 0.9990592664126643

# %%
recall_score(y_test, y_pred_rf, pos_label='Non-Covid')
# Out:
# 0.9987468671679198

# %%
#Support Vector Machine

# %%
from sklearn.svm import SVC

# %%
svm = SVC(probability=True)
svm.fit(X_train_pca, y_train)
# Out:
# SVC(probability=True)

# %%
with open("svm_henor.pk","wb") as f:
    pickle.dump(svm, f)

# %%
with open('svm_henor.pk', 'rb') as pickle_file:
    svm = pickle.load(pickle_file)

# %%
y_pred_svm=svm.predict(X_test_pca)

# %%
y_pred_svm
# Out:
# array(['Covid', 'Non-Covid', 'Covid', ..., 'Covid', 'Non-Covid', 'Covid'],
#       dtype=object)

# %%
conf_matrix = confusion_matrix(y_test,y_pred_svm)
conf_matrix
# Out:
# array([[1576,   17],
#        [  35, 1561]], dtype=int64)

# %%
accuracy_score(y_test, y_pred_svm)
# Out:
# 0.9836939479460646

# %%
precision_score(y_test, y_pred_svm,average='weighted')
# Out:
# 0.9837557682981197

# %%
recall_score(y_test, y_pred_svm, average='weighted')
# Out:
# 0.9836939479460646

# %%
f1_score(y_test, y_pred_svm, average='weighted')
# Out:
# 0.9836935150205731

# %%
recall_score(y_test, y_pred_svm, pos_label='Non-Covid')
# Out:
# 0.9780701754385965

# %%
#Ridge Classifier

# %%
from sklearn.linear_model import RidgeClassifier

# %%
rdgclassifier = RidgeClassifier()
rdgclassifier.fit(X_train_pca, y_train)
# Out:
# RidgeClassifier()

# %%
y_pred_rdge=rdgclassifier.predict(X_test_pca)

# %%
y_pred_rdge
# Out:
# array(['Covid', 'Non-Covid', 'Covid', ..., 'Non-Covid', 'Covid', 'Covid'],
#       dtype='<U9')

# %%
conf_matrix = confusion_matrix(y_test,y_pred_rdge)
conf_matrix
# Out:
# array([[1217,  376],
#        [ 512, 1084]], dtype=int64)

# %%
accuracy_score(y_test, y_pred_rdge)
# Out:
# 0.7215428033866416

# %%
precision_score(y_test, y_pred_rdge,average='weighted')
# Out:
# 0.7231885646389089

# %%
recall_score(y_test, y_pred_rdge, average='weighted')
# Out:
# 0.7215428033866416

# %%
f1_score(y_test, y_pred_rdge, average='weighted')
# Out:
# 0.7210466727822125

# %%
recall_score(y_test, y_pred_rdge, pos_label='Non-Covid')
# Out:
# 0.6791979949874687
