# %%
import os
import glob
import pandas as pd

# %%
csv_files = glob.glob('*.{}'.format('csv'))
csv_files
# Out:
# ['AdaptiveHistogram.csv',
#  'CovidAdaptiveHistogram.csv',
#  'CovidHistogramEqualized.csv',
#  'CovidImages.csv',
#  'Images.csv',
#  'NormalAdaptiveHistogram.csv',
#  'NormalHistogramEqualized.csv',
#  'NormalImages.csv']

# %%
#Merging CovidAdaptiveHistogram+NormalAdaptiveHistogram

# %%
csv_files = glob.glob('*AdaptiveHistogram.{}'.format('csv'))
csv_files
# Out:
# ['CovidAdaptiveHistogram.csv', 'NormalAdaptiveHistogram.csv']

# %%
df_concat = pd.concat([pd.read_csv(f) for f in csv_files ], ignore_index=True)
df_concat
# Out:
#        Column1  Column2  Column3  Column4  Column5  Column6  Column7  Column8  \
# 0          9.0      9.0      9.0      9.0      9.0      9.0      9.0      9.0
# 1          3.0      3.0      8.0     11.0     11.0     10.0     10.0     10.0
# 2          9.0      9.0      9.0      9.0      9.0      9.0      9.0      9.0
# 3         10.0      9.0      9.0      9.0     10.0     10.0     10.0      9.0
# 4          9.0      9.0      9.0     10.0     10.0     10.0     10.0     10.0
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 15937     55.0     55.0    151.0    173.0    153.0    183.0    208.0    214.0
# 15938     69.0     71.0     58.0     62.0    148.0    161.0    145.0    155.0
# 15939     62.0     61.0     50.0    122.0    155.0    147.0    183.0    221.0
# 15940     65.0     62.0     53.0    130.0    157.0    157.0    194.0    223.0
# 15941    153.0    179.0    218.0    217.0    218.0    214.0    198.0    228.0
#
# ...

# %%
df_concat.to_csv('E:/project/AdaptiveHistogram.csv')

# %%
#Merging CovidHistogramEqualized +NormalHistogramEqualized

# %%
csv_files = glob.glob('*HistogramEqualized.{}'.format('csv'))
csv_files
# Out:
# ['CovidHistogramEqualized.csv', 'NormalHistogramEqualized.csv']

# %%
df_concat = pd.concat([pd.read_csv(f) for f in csv_files ], ignore_index=True)
df_concat
# Out:
#        Column1  Column2  Column3  Column4  Column5  Column6  Column7  Column8  \
# 0         41.0     42.0     43.0     44.0     44.0     44.0     44.0     44.0
# 1          0.0      0.0     24.0     38.0     38.0     37.0     36.0     34.0
# 2         39.0     38.0     37.0     38.0     36.0     39.0     39.0     37.0
# 3         46.0     45.0     47.0     46.0     47.0     50.0     48.0     47.0
# 4         22.0     21.0     21.0     24.0     26.0     26.0     25.0     25.0
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 15937      4.0     10.0    134.0    160.0    145.0    178.0    208.0    218.0
# 15938     10.0     14.0      4.0     24.0    143.0    163.0    148.0    156.0
# 15939     11.0     10.0      8.0    115.0    174.0    165.0    193.0    229.0
# 15940     11.0      7.0      9.0    123.0    176.0    172.0    202.0    231.0
# 15941    164.0    184.0    215.0    212.0    206.0    198.0    195.0    227.0
#
# ...

# %%
df_concat.to_csv('E:/project/HistogramEqualized.csv')
